# %% [raw]
# ---
# layout: post
# toc: True
# breadcrumb: True
# title: JS Variables Homework
# description: These are the homework problems and popcorn hacks.
# permalink: /csse/javascript/fundamentals/variables-hw
# author: Samarth H, Anish G, Krish K, Pranay K
# ---

# %% [markdown]
# <style>
# .glowing-text {
#   color: #fff; /* Set the text color to white or a light color for better contrast */
#   text-shadow: 0 0 10px #8a2be2, /* Purple glow */
#                0 0 20px #8a2be2, /* Deeper purple glow */
#                0 0 30px #4169e1, /* Blue glow */
#                0 0 40px #4169e1; /* Deeper blue glow */
#
#   font-weight: bold;
#   margin-top: 0;
# }
# </style>
#
# Presented by the
# <h4 class="glowing-text">TINKERERS</h4>
#
# <hr>
#
# # <div style="font-weight:bold; text-decoration:underline;">Popcorn Hack 1 🍿😈</div>
#
# Let's start diving into some of the questions.
#
# ## Instructions
#
# Below instructions refer to this code cell:

# %%
# %%html
#
# <html>
# <body>
#   <h2>Popcorn Hack 1 Output</h2>
#   <div id="output1"></div>
#
#   <script>
#   (() => {
#
#     let name = "Krystal";
#     const age = 15;
#
#     // In practice, you shouldn't use var. This is just for the purposes of teaching :)
#     var city = "San Diego";
#
#     // Change vars here
#     name = "Krystal";
#     //age = 2;
#     city = "4s ranch";
#
#     // new hobby is added here
#     let hobby = "painting";
#
#     // Build the output string with variable types
#   let outputText =
#     name + " (" + typeof name + ") is " +
#     age + " (" + typeof age + ") years old, lives in " +
#     city + " (" + typeof city + "), and loves " +
#     hobby + " (" + typeof hobby + ").";
#
#   // Display in DOM
#   document.getElementById("output1").innerText = outputText;
#
#   // Also log to console
#   console.log(outputText);
#
# })();
# </script>
#
# </body>
# </html>
# Out:
# <html>
# <body>
#   <h2>Popcorn Hack 1 Output</h2>
#   <div id="output1"></div>
#
#   <script>
#   (() => {
#
#     let name = "Krystal";
#     const age = 15;
#
#     // In practice, you shouldn't use var. This is just for the purposes of teaching :)
#     var city = "San Diego";
#
#     // Change vars here
#     name = "Krystal";
#     //age = 2;
#     city = "4s ranch";
#
#     // new hobby is added here
#     let hobby = "painting";
#
#     // Build the output string with variable types
#   let outputText =
#     name + " (" + typeof name + ") is " +
#     age + " (" + typeof age + ") years old, lives in " +
#     city + " (" + typeof city + "), and loves " +
#     hobby + " (" + typeof hobby + ").";
#
#   // Display in DOM
#   document.getElementById("output1").innerText = outputText;
#
#   // Also log to console
#   console.log(outputText);
#
# })();
# </script>
#
# </body>
# </html>

# %% [markdown]
# Now, do the below with this code.
#
# 1. Adjust var declarations, names, values, etc. Mess around with it and observe any changes/errors.
# 2. Think and/or discuss with your table: what changes did you notice?
#
# Now let's make some changes :)
#
# 3. Uncomment the line saying `age = 2;` and look at your console. What do you notice?
#
# 4. Add a new variable called `hobby` with the value of "painting" and update the DOM output and console output to say:
#    "[NAME] is [AGE] years old, lives in [CITY], and loves [HOBBY]"
#
# 5. There's a keyword called `typeof` in JavaScript. Use this keyword to also display the data types of the variables.
#    Example: `typeof "John"` gives `"string"` and `typeof 3.14` gives `"number"`

# %% [markdown]
# <hr>
#
# # <div style="font-weight:bold; text-decoration:underline;">Popcorn Hack 2 🍿😈</div>
#
# Follow the below instructions.
#
# 1. Go to the code cell below this text.
# 2. Using the correct JS variable naming convention, declare a Magic Number variable with the value returned by `input.value` to get a user response.
# 3. Convert it to a Number data type using Number(). Example: `let x = Number(x);` turns x into a Number. This is because prompt() always returns Strings.
# 4. Create variables `doubled`, `squared`, and `tripled` that contain the doubled, squared, and tripled values of the magic number.
# 5. Display the results in DOM and the console by changing output.innerText and using console.log().

# %%
# %%html
#
# <html>
# <body>
#
#     <p>Click the button after entering your magic number!</p>
#
#     <input type="number" id="magicInput" placeholder="Enter magic number">
#     <button id="magicButton">Calculate</button>
#
#     <div id="output2">Your results will appear here.</div>
#
#     <script>
#     (() => {
#
#     const button = document.getElementById("magicButton");
#     const input = document.getElementById("magicInput");
#     const output = document.getElementById("output2");
#
#     button.addEventListener("click", () => {
#
#       // ^^ DO NOT MODIFY ANY ABOVE CODE ^^
#
#       // Set the Magic Number variable to input.value
#
#        <input type="number" id="magicNumber" placeholder="Enter magic number">
# <button id="submitBtn">Submit</button>
# <div id="output"></div>
#
# <script>
# document.getElementById("submitBtn").addEventListener("click", () => {
#   // Declare magicNumber using correct naming convention
#   let magicNumber = Number(document.getElementById("magicNumber").value);
#
#   let doubled = magicNumber * 2;
#   let squared = magicNumber * magicNumber;
#   let half = magicNumber / 2;
#
#   document.getElementById("output").innerText =
#     "Doubled: " + doubled + ", Squared: " + squared + ", Half: " + half;
#
#   console.log("Doubled: " + doubled + ", Squared: " + squared + ", Half: " + half);
# });
#     });
#
#     })();
#
#   </script>
#
# </body>
# </html>
# Out:
# <html>
# <body>
#
#     <p>Click the button after entering your magic number!</p>
#
#     <input type="number" id="magicInput" placeholder="Enter magic number">
#     <button id="magicButton">Calculate</button>
#
#     <div id="output2">Your results will appear here.</div>
#
#     <script>
#     (() => {
#
#     const button = document.getElementById("magicButton");
#     const input = document.getElementById("magicInput");
#     const output = document.getElementById("output2");
#
#     button.addEventListener("click", () => {
#
#       // ^^ DO NOT MODIFY ANY ABOVE CODE ^^
#
#       // Set the Magic Number variable to input.value
#
#        <input type="number" id="magicNumber" placeholder="Enter magic number">
# <button id="submitBtn">Submit</button>
# <div id="output"></div>
#
# <script>
# document.getElementById("submitBtn").addEventListener("click", () => {
#   // Declare magicNumber using correct naming convention
#   let magicNumber = Number(document.getElementById("magicNumber").value);
#
#   let doubled = magicNumber * 2;
#   let squared = magicNumber * magicNumber;
#   let half = magicNumber / 2;
#
#   document.getElementById("output").innerText =
#     "Doubled: " + doubled + ", Squared: " + squared + ", Half: " + half;
#
#   console.log("Doubled: " + doubled + ", Squared: " + squared + ", Half: " + half);
# });
#     });
#
#     })();
#
#   </script>
#
# </body>
# </html>

# %% [markdown]
# <hr>
#
# # Variables Homework (Show what you know!)
#
# ### Homework Problems: Understanding JavaScript Variables
#
# There is a code block below the image saying "Have Fun!" Write your code in there.
#
# ### <span style="color: white; text-shadow: 2px 2px 5px white;"> Part A - Creating Variables</span>
#
# 1. Create a variable called `name` and store your first name in it. Print it in the console and to DOM.
#
#
# 2. Create two variables `age` and `city`. Print them in a single sentence like:
#         - "I am 15 years old and I live in New York."
#
#
# 4. Create two number variables num1 = 10 and num2 = 5. Print their sum, difference, product, and quotient.
#
#
# 1. Make a variable `favoriteFood` and print:
#     My favorite food is ____."
#
# ### <span style="color: white; text-shadow: 2px 2px 5px white;">Part C – Practice Problems</span>
#
#
# 6. Swap the values of two variables: x = 7 and y = 3.
#
#
# 7. Create a variable `fullName` by joining two strings: "FirstName" and "LastName".
#
#
# 8. Convert temperature C = 25 into Fahrenheit using F = (C * 9/5) + 32.
#
#
# 9. Create a variable score = 85.
#     - Print "Pass" if score >= 50, else "Fail".
#
#
#
# 10. Write a program that asks for your name and age (use prompt)
#      and prints: "Hello <name>, you are <age> years old."
#
# 11. Make a project that uses 5 variables to run. It can do anything yuou want, have fun and good luck!
#
# Extra credit (optional):
#     Instead of hard coding the variable for number 9 to 85, make the variable a random number from 1-100.
#
# ![An image of have fun](https://as2.ftcdn.net/jpg/05/52/30/29/1000_F_552302940_Nct9zn3a6us0igBJqlkDQzQnbM4LLvmS.jpg "An image of have fun")

# %%
# %%html
#
# <html>
#
# <body>
#  <h2>Homework Output</h2>
# <div id="output"></div>
#
# <script>
# document.getElementById("output").innerHTML = ""; // Clear output
#
# (() => {
#   // Create a variable called `name` and store your first name
#   let name = "Krystal";
#
#   // Print it to the console
#   console.log(name);
#
#   // Print it to the DOM on a new line
#   document.getElementById("output").innerHTML += name + "<br>";
#
#   // Create variables
#   let age = 15;
#   let city = "New York";
#
#   // Print to console
#   console.log("I am " + age + " years old and I live in " + city + ".");
#
#   // Print to DOM
#   document.getElementById("output").innerHTML +=
#     "I am " + age + " years old and I live in " + city + "." + "<br>";
#
#     //  add hobby variable
#   let hobby = "painting";
#
#   // Print hobby to console
#   console.log("I love " + hobby + ".");
#
#   // Print hobby to DOM
#   document.getElementById("output").innerHTML += "I love " + hobby + "." + "<br>";
#
#  //  Create two number variables
#   let num1 = 10;
#   let num2 = 5;
#
#   // Calculate sum, difference, product, quotient
#   let sum = num1 + num2;
#   let difference = num1 - num2;
#   let product = num1 * num2;
#   let quotient = num1 / num2;
#
#   // Print results to console
#   console.log("Sum: " + sum);
#   console.log("Difference: " + difference);
#   console.log("Product: " + product);
#   console.log("Quotient: " + quotient);
#
#   // Print results to DOM
#   document.getElementById("output").innerHTML += "Sum: " + sum + "<br>";
#   document.getElementById("output").innerHTML += "Difference: " + difference + "<br>";
#   document.getElementById("output").innerHTML += "Product: " + product + "<br>";
#   document.getElementById("output").innerHTML += "Quotient: " + quotient + "<br>";
#
#   // Add favoriteFood variable
#   let favoriteFood = "all food";
#
#   // Print favoriteFood to console
#   console.log("My favorite food is " + favoriteFood + ".");
#
#   // Print favoriteFood to DOM
#   document.getElementById("output").innerHTML +=
#     "My favorite food is " + favoriteFood + "." + "<br>";
#
#
#   // 6️⃣ Swap the values of two variables x = 7 and y = 3
#   let x = 7;
#   let y = 3;
#
#   console.log("Before swap: x = " + x + ", y = " + y);
#   document.getElementById("output").innerHTML +=
#     "Before swap: x = " + x + ", y = " + y + "<br>";
#
#   // Swap using a temporary variable
#   let temp = x;
#   x = y;
#   y = temp;
#
#   console.log("After swap: x = " + x + ", y = " + y);
#   document.getElementById("output").innerHTML +=
#     "After swap: x = " + x + ", y = " + y + "<br>";
#
#     // Create a variable fullName by joining two strings
#   let fullName = "Krystal" + " " + "Torres";
#
#   // Print fullName to console
#   console.log("Full Name: " + fullName);
#
#   // Print fullName to DOM
#   document.getElementById("output").innerHTML +=
#     "Full Name: " + fullName + "<br>";
#
#
#   //  Convert temperature C = 25 to Fahrenheit
#   let C = 25;
#   let F = (C * 9/5) + 32;
#
#   // Print temperature conversion to console
#   console.log(C + "°C is " + F + "°F");
#
#   // Print temperature conversion to DOM
#   document.getElementById("output").innerHTML +=
#     C + "°C is " + F + "°F<br>";
#
#
#   // Create score variable and print Pass/Fail
#   let score = 85;
#   let result = (score >= 50) ? "Pass" : "Fail";
#
#   // Print to console
#   console.log("Score: " + score + " - " + result);
#
#   // Print to DOM
#   document.getElementById("output").innerHTML +=
#     "Score: " + score + " - " + result + "<br>";
#
#
#
#     // Prompt for name and age (works even if prompt() returns null)
#   let userName = prompt("Enter your name:") || "User";
#   let userAge = prompt("Enter your age:") || "unknown";
#
#   console.log("Hello " + userName + ", you are " + userAge + " years old.");
#   document.getElementById("output").innerHTML +=
#     "Hello " + userName + ", you are " + userAge + " years old.<br>";
#
#
#     // Random Fun Generator (5 variables)
#   document.getElementById("output").innerHTML += "<br>"; // Spacer
#
#   let namesList = ["Alice", "Bob", "Charlie", "Dana", "Eli"];
#   let randomName = namesList[Math.floor(Math.random() * namesList.length)];
#
#   let randomAge = Math.floor(Math.random() * 41) + 10;
#
#   let citiesList = ["New York", "Paris", "Tokyo", "Sydney", "Rio"];
#   let randomCity = citiesList[Math.floor(Math.random() * citiesList.length)];
#
#   let hobbiesList = ["painting", "gaming", "reading", "biking", "cooking"];
#   let randomHobby = hobbiesList[Math.floor(Math.random() * hobbiesList.length)];
#
#   let foodsList = ["pizza", "sushi", "tacos", "ice cream", "pasta"];
#   let randomFood = foodsList[Math.floor(Math.random() * foodsList.length)];
#
#   let funSentence = randomName + " is " + randomAge + " years old, lives in " + randomCity +
#                     ", loves " + randomHobby + ", and their favorite food is " + randomFood + "!";
#
#   console.log(funSentence);
#   document.getElementById("output").innerHTML += funSentence + "<br>";
# })();
# </script>
#
# </body>
# </html>
# Out:
# <html>
#
# <body>
#  <h2>Homework Output</h2>
# <div id="output"></div>
#
# <script>
# document.getElementById("output").innerHTML = ""; // Clear output
#
# (() => {
#   // Create a variable called `name` and store your first name
#   let name = "Krystal";
#
#   // Print it to the console
#   console.log(name);
#
#   // Print it to the DOM on a new line
#   document.getElementById("output").innerHTML += name + "<br>";
#
#   // Create variables
#   let age = 15;
#   let city = "New York";
#
#   // Print to console
#   console.log("I am " + age + " years old and I live in " + city + ".");
#
#   // Print to DOM
#   document.getElementById("output").innerHTML +=
#     "I am " + age + " years old and I live in " + city + "." + "<br>";
#
#     //  add hobby variable
#   let hobby = "painting";
#
#   // Print hobby to console
#   console.log("I love " + hobby + ".");
#
#   // Print hobby to DOM
#   document.getElementById("output").innerHTML += "I love " + hobby + "." + "<br>";
#
#  //  Create two number variables
#   let num1 = 10;
#   let num2 = 5;
#
#   // Calculate sum, difference, product, quotient
#   let sum = num1 + num2;
#   let difference = num1 - num2;
#   let product = num1 * num2;
#   let quotient = num1 / num2;
#
#   // Print results to console
#   console.log("Sum: " + sum);
#   console.log("Difference: " + difference);
#   console.log("Product: " + product);
#   console.log("Quotient: " + quotient);
#
#   // Print results to DOM
#   document.getElementById("output").innerHTML += "Sum: " + sum + "<br>";
#   document.getElementById("output").innerHTML += "Difference: " + difference + "<br>";
#   document.getElementById("output").innerHTML += "Product: " + product + "<br>";
#   document.getElementById("output").innerHTML += "Quotient: " + quotient + "<br>";
#
#   // Add favoriteFood variable
#   let favoriteFood = "all food";
#
#   // Print favoriteFood to console
#   console.log("My favorite food is " + favoriteFood + ".");
#
#   // Print favoriteFood to DOM
#   document.getElementById("output").innerHTML +=
#     "My favorite food is " + favoriteFood + "." + "<br>";
#
#
#   // 6️⃣ Swap the values of two variables x = 7 and y = 3
#   let x = 7;
#   let y = 3;
#
#   console.log("Before swap: x = " + x + ", y = " + y);
#   document.getElementById("output").innerHTML +=
#     "Before swap: x = " + x + ", y = " + y + "<br>";
#
#   // Swap using a temporary variable
#   let temp = x;
#   x = y;
#   y = temp;
#
#   console.log("After swap: x = " + x + ", y = " + y);
#   document.getElementById("output").innerHTML +=
#     "After swap: x = " + x + ", y = " + y + "<br>";
#
#     // Create a variable fullName by joining two strings
#   let fullName = "Krystal" + " " + "Torres";
#
#   // Print fullName to console
#   console.log("Full Name: " + fullName);
#
#   // Print fullName to DOM
#   document.getElementById("output").innerHTML +=
#     "Full Name: " + fullName + "<br>";
#
#
#   //  Convert temperature C = 25 to Fahrenheit
#   let C = 25;
#   let F = (C * 9/5) + 32;
#
#   // Print temperature conversion to console
#   console.log(C + "°C is " + F + "°F");
#
#   // Print temperature conversion to DOM
#   document.getElementById("output").innerHTML +=
#     C + "°C is " + F + "°F<br>";
#
#
#   // Create score variable and print Pass/Fail
#   let score = 85;
#   let result = (score >= 50) ? "Pass" : "Fail";
#
#   // Print to console
#   console.log("Score: " + score + " - " + result);
#
#   // Print to DOM
#   document.getElementById("output").innerHTML +=
#     "Score: " + score + " - " + result + "<br>";
#
#
#
#     // Prompt for name and age (works even if prompt() returns null)
#   let userName = prompt("Enter your name:") || "User";
#   let userAge = prompt("Enter your age:") || "unknown";
#
#   console.log("Hello " + userName + ", you are " + userAge + " years old.");
#   document.getElementById("output").innerHTML +=
#     "Hello " + userName + ", you are " + userAge + " years old.<br>";
#
#
#     // Random Fun Generator (5 variables)
#   document.getElementById("output").innerHTML += "<br>"; // Spacer
#
#   let namesList = ["Alice", "Bob", "Charlie", "Dana", "Eli"];
#   let randomName = namesList[Math.floor(Math.random() * namesList.length)];
#
#   let randomAge = Math.floor(Math.random() * 41) + 10;
#
#   let citiesList = ["New York", "Paris", "Tokyo", "Sydney", "Rio"];
#   let randomCity = citiesList[Math.floor(Math.random() * citiesList.length)];
#
#   let hobbiesList = ["painting", "gaming", "reading", "biking", "cooking"];
#   let randomHobby = hobbiesList[Math.floor(Math.random() * hobbiesList.length)];
#
#   let foodsList = ["pizza", "sushi", "tacos", "ice cream", "pasta"];
#   let randomFood = foodsList[Math.floor(Math.random() * foodsList.length)];
#
#   let funSentence = randomName + " is " + randomAge + " years old, lives in " + randomCity +
#                     ", loves " + randomHobby + ", and their favorite food is " + randomFood + "!";
#
#   console.log(funSentence);
#   document.getElementById("output").innerHTML += funSentence + "<br>";
# })();
# </script>
#
# </body>
# </html>

# %% [markdown]
# # Submission
#
# You will submit the link to your homework on a web page in the below form.
# If you are unable to get your homework accessible from the website, you can upload this Jupyter notebook to the form.
#
# **IMPORTANT: If uploading, please name this Jupyter notebook in this format: [FirstName][LastName]_vars_hw.ipynb**
# Example: SamarthHande_hw.ipynb
#
# <https://forms.gle/UBDFErZpKpTApWap8>
#
# Requirements for homework:
# 1. Parts A, B, and C should be completed. You will get .3 points for each question completed.
# 2. Up to 0.03 extra points will be given to code that demonstrates exceptional creativity and comprehension.

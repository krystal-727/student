# %% [markdown]
# Notes:
# - when making your game replace background just change images
# - instead of just put in an image you put in a spreadsheet to have ur character move
# - ex of spreadhseet > oreientation: {rows: 4, columns: 3},
# - enemy.js made for you aready
# - she made imaginary box for enemy to jump around in so it ould be in constant movement
# - game inside game
# - wasd for controls
# - use copilot to help with your idea
#
# TIPS:
# - dont commit again and again,  use make to see your changes
# - make sure your commits dont have too many changes inside
# - try not to change too many things inide the given prompts and resources provided
#
# Extra notes:
# - to present she pull request into page website but do not work inside pages from the start
# -
